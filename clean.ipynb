# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

Ruta = '/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data/attacks.csv'
data = pd.read_csv(Ruta, encoding="latin1") #, errors='ignore', low_memory=False

# %%
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
#hacemos una copia de seguridad de la data
data2 = data

# %%
#vamos a ver las dimensiones de nuestra data original (25723, 24)
data.shape
# Out:
# (25723, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
name_columns = data.columns
name_columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
#vamos a visualizar valores nulos

# %%
nan_cols = data.isna().sum()
nan_cols
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#eliminamos valores duplicados. hay muchas columnas con todos los valores en blanco
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (6312, 24)

# %%
#data.to_csv('DataLimpieza1.csv', index=False, sep=',')

# %%
#eliminamos resto de filas que en la columna de Case Number sigue estando en blanco
data.dropna(inplace=True, subset=['Case Number'])
data.shape
# Out:
# (6310, 24)

# %%
#volvemos a visualizar valores nulos
nan_cols = data.isna().sum()
nan_cols
# Out:
# Case Number                  0
# Date                         9
# Year                        11
# Type                        13
# Country                     59
# Area                       464
# Location                   549
# Activity                   553
# Name                       219
# Sex                        574
# Age                       2839
# Injury                      37
# Fatal (Y/N)                548
# Time                      3362
# Species                   2846
# Investigator or Source      26
# pdf                          9
# href formula                10
# href                         9
# Case Number.1                9
# Case Number.2                9
# original order               2
# Unnamed: 22               6309
# Unnamed: 23               6308
# dtype: int64

# %%
case_0 = data[data['Case Number']=='0'].index
case_0

data.drop(case_0, axis=0, inplace=True)

# %%
data.shape
# Out:
# (6302, 24)

# %%
delete_Case_Number = data[(data['Case Number']=='xx')].index
delete_Case_Number
data.drop(delete_Case_Number, axis=0, inplace=True)

# %%
data.shape
# Out:
# (6301, 24)

# %%
#data.to_csv('DataLimpieza.csv', index=False, sep=',')

# %%
delete2 = data[(data['Date']=='F')].index
delete2
# Out:
# Int64Index([], dtype='int64')

# %%
data[['Case Number']].isnull().sum()
# Out:
# Case Number    0
# dtype: int64

# %%
data.shape
# Out:
# (6301, 24)

# %%
#data.to_csv('DataLimpieza3.csv', index=True, sep=',')

# %%
len(data.columns)
# Out:
# 24

# %%
new_name_columns = []
for e in data.columns:
    new_name_columns.append(e.rstrip())
    
new_name_columns
# Out:
# ['Case Number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species',
#  'Investigator or Source',
#  'pdf',
#  'href formula',
#  'href',
#  'Case Number.1',
#  'Case Number.2',
#  'original order',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
data.columns = new_name_columns
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
new_name_columns = []
for e in data.columns:
    new_name_columns.append(e.capitalize())
    
new_name_columns
# Out:
# ['Case number',
#  'Date',
#  'Year',
#  'Type',
#  'Country',
#  'Area',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal (y/n)',
#  'Time',
#  'Species',
#  'Investigator or source',
#  'Pdf',
#  'Href formula',
#  'Href',
#  'Case number.1',
#  'Case number.2',
#  'Original order',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
data.columns = new_name_columns
data.columns
# Out:
# Index(['Case number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (y/n)', 'Time',
#        'Species', 'Investigator or source', 'Pdf', 'Href formula', 'Href',
#        'Case number.1', 'Case number.2', 'Original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
case_0 = data[data['Year']==0.0].index
case_0

data.drop(case_0, axis=0, inplace=True)
data.shape
# Out:
# (6176, 24)

# %%
data['Year'].dropna(inplace=True)

# %%
data.shape
# Out:
# (6176, 24)

# %%
#data.to_csv('DataLimpieza.csv', index=True, sep=';')

# %%
data.Date = data.Date.astype(str)

# %%
Date2 = []
for i in data.Date:
    Date2.append(i.replace('Reported',''))

data.Date = Date2

# %%
Date2 = []
for i in data.Date:
    Date2.append(i.strip())

data.Date = Date2

# %%
#eliminamos los index de las localidades, areas y countrys que estan vacios los 3
no_local = data[data.Country.isnull() & data.Area.isnull() & data.Location.isnull()].index
data.drop(no_local, axis=0, inplace=True)

# %%
data.shape
# Out:
# (6149, 24)

# %%
#calculamos el total de ataques
total = data.shape[0]
total
data['Country'].value_counts() / total * 100
# Out:
# USA                         35.957066
# AUSTRALIA                   21.499431
# SOUTH AFRICA                 9.286063
# PAPUA NEW GUINEA             2.114165
# NEW ZEALAND                  2.065376
#                               ...
# NORTH SEA                    0.016263
# RED SEA / INDIAN OCEAN       0.016263
# BRITISH WEST INDIES          0.016263
# ADMIRALTY ISLANDS            0.016263
# Between PORTUGAL & INDIA     0.016263
# Name: Country, Length: 206, dtype: float64

# %%
#desechamos todos los countrys que no sean USA, Australia y South africa, puesto que vamos a analizar esots 3 countrys que supone el 65% de los ataques.

no_country = data[(data['Country']!="USA") & (data['Country']!="AUSTRALIA")& (data['Country']!="SOUTH AFRICA")].index
no_country

data.drop(no_country, axis=0, inplace=True)
data.shape
# Out:
# (4104, 24)

# %%
#data.to_csv('DataLimpieza2.csv', index=True, sep=';')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4104 entries, 0 to 6176
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case number             4104 non-null   object
#  1   Date                    4104 non-null   object
#  2   Year                    4103 non-null   float64
#  3   Type                    4103 non-null   object
#  4   Country                 4104 non-null   object
#  5   Area                    4086 non-null   object
#  6   Location                4010 non-null   object
#  7   Activity                3808 non-null   object
#  8   Name                    4042 non-null   object
#  9   Sex                     3801 non-null   object
#  10  Age                     2589 non-null   object
#  11  Injury                  4093 non-null   object
#  12  Fatal (y/n)             3740 non-null   object
#  13  Time                    2328 non-null   object
# ...

# %%
# convertimos todas las columnas en str
data.columns = data.columns.astype(str)

# %%
data['Area'] = data['Area'].astype(str)
for i in data['Area']:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
data_copy = data

# %%
data_copy.shape
# Out:
# (4104, 24)

# %%
#homogenizamos columna Area
No_spacios = []
data['Area'] = data['Area'].astype(str)
for i in data['Area']:
    a=(i.strip())
    b=(a.replace('  Province',' Province'))
    c=(b.replace('KwaZulu-Natal between Port Edward and Port St Johns','KwaZulu-Natal'))
    No_spacios.append(c)
 
data['Area'] = No_spacios 

#Exportamos para probar
#data.to_csv('DataLimpieza99.csv', index=True, sep=';')

# %%
no_year = data[(data['Year']=="nan") | (data['Year']=="5.0")].index
no_year

data.drop(no_year, axis=0, inplace=True)

# %%
#homogenizamos columna Year
Normalizar = []
data['Year'] = data['Year'].astype(str)
for i in data['Year']:
    a=(i.strip())
    b=(a.replace('.0',''))
    Normalizar.append(b) 

data['Year'] = Normalizar

#Exportamos para probar
#data.to_csv('DataLimpieza98.csv', index=True, sep=';')

# %%
no_area = data[(data['Area']=="nan")].index
no_area

data.drop(no_area, axis=0, inplace=True)

# %%
data['Area'] = data['Area'].replace('Westerm Australia','Western Australia')

# %%
#Exportamos para probar
data.to_csv('DataLimpieza98.csv', index=True, sep=';')

# %%
#homogenizamos columna Sex
Normalizar = []
data['Sex'] = data['Sex'].astype(str)
for i in data['Sex']:
    a=(i.strip())
    b=(a.replace('lli','M'))
    c=(b.replace('M ','M'))
    Normalizar.append(c) 

data['Sex'] = Normalizar

#Exportamos para probar
#data['Sex'] = data['Sex'].astype(int)
#data.to_csv('DataLimpieza97.csv', index=True, sep=';')

# %%
data.shape
# Out:
# (4086, 24)

# %%
no_sex = data[(data['Sex']=="nan") | (data['Sex']=="N")].index
len(no_sex)

data.drop(no_sex, axis=0, inplace=True)
data.shape
# Out:
# (3784, 24)

# %%
data.to_csv("/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data pruebas/DataLimpieza96.csv", index=True, sep=';')

# %%
#rellenamos los valores en blanco de la columna edad con desconocido
data['Age'] = data['Age'].astype(str) #cambiamos valores a str para poder reemplazar
data['Age'] = data['Age'].replace('nan','0')

# %%
data.to_csv("/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data pruebas/DataLimpieza93.csv", index=True, sep=';')
# Out:
#   Input In [91]
#     def exportar:
#                 ^
# SyntaxError: invalid syntax

# %%
borrar=['  ', '?    &   14', '? & 19', '"young"', '>50', '¬† ', '10 or 12', '12 or 13', '16 to 18', '17 & 35', '2¬Ω', '20s', '21 or 26', '23 & 20', '25 or 28', '30 & 32', '30 or 36', '30s', '31 or 33', '33 or 37', '37, 67, 35, 27,  ? & 27', '40s' '50s', '6¬Ω', '60\'s', '60s', '7      &    31', '8 or 10', 'adult', 'Both 11', 'Ca. 33', 'Elderly', 'F', 'mid-20s', 'mid-30s', 'Teen', 'Teens', 'young']
age_2 = []

for i in data['Age']:
    if i in borrar:
        a=(i.replace(i,'Borrar'))
        age_2.append(a)
    else:
        age_2.append(i)
        
data['Age'] = age_2

# %%
data.to_csv("/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data pruebas/DataLimpieza93.csv", index=True, sep=';')

# %%
def exportar():
    data.to_csv("/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data pruebas/DataLimpieza93.csv", index=True, sep=';')

# %%
borrar=['40s', '50s', 'teen', '¬†','6¬Ω','2¬Ω']
age_2 = []

for i in data['Age']:
    if i in borrar:
        a=(i.replace(i,'Borrar'))
        age_2.append(a)
    else:
        age_2.append(i)

data['Age'] = age_2

# %%
#homogenizamos columna Age
Normalizar = []
data['Age'] = data['Age'].astype(str)
for i in data['Age']:
    if i == '\¬† ' or i == '2\¬Ω' or i == '2\½' or i == '2\½' or i == 'Borrar' or i == '0':
        Normalizar.append('Unknow')
    else:
        Normalizar.append(i)        

data['Age'] = Normalizar

# %%
data['Age'].value_counts()
# Out:
# Unknow    1277
# 17         125
# 18         115
# 16         106
# 15         106
#           ...
# 67           1
# 74           1
# 45           1
#  43          1
#              1
# Name: Age, Length: 83, dtype: int64

# %%
no_Age = (1824)
no_Age

data.drop(no_Age, axis=0, inplace=True)
data.shape
# Out:
# (3783, 24)

# %%
#limpiamos dos valores residuales de year
no_Year = data[(data['Year']=="nan") | (data['Year']=="5")].index
no_Year

data.drop(no_Year, axis=0, inplace=True)
data.shape
# Out:
# (3781, 24)

# %%
data['Year'] = data['Year'].astype(int)

# %%
exportar()

# %%
data['Species'] = data['Species'].astype(str)

# %%
buscar = [f'5\'']
texto = ("nada5\'")

x = texto.find(f'5\'')
x
# Out:
# 4

# %%
new_Species = []

for i in data['Species']:
    if i.find('White') >= 0:
        new_Species.append('Shark White')
    elif i.find('Tiger') >= 0:
        new_Species.append('Shark Tiger')
    elif i.find('Small') >= 0:
        new_Species.append('Shark Small')
    elif i.find('Dusky') >= 0:
        new_Species.append('Shark Dusky')        
    elif i.find('Blue') >= 0:
        new_Species.append('Shark Blue')
    elif i.find('Bull') >= 0:
        new_Species.append('Shark Bull')  
    elif i.find('Sand') >= 0:
        new_Species.append('Shark Sand')
    elif i.find('Gray') >= 0:
        new_Species.append('Shark Gray')          
    elif i.find('Reef') >= 0:
        new_Species.append('Shark Reef')
    elif i.find('Wobbegong') >= 0:
        new_Species.append('Shark Wobbegong')          
    elif i.find('Bronze') >= 0:
        new_Species.append('Shark Bronze')
    elif i.find('Lemon') >= 0:
        new_Species.append('Shark Lemon')          
    elif i.find('Blacktip') >= 0:
        new_Species.append('Shark Blacktip')
    elif i.find('Nurse') >= 0:
        new_Species.append('Shark Nurse')          
    elif i.find('Zambesi') >= 0:
        new_Species.append('Shark Zambesi')
    elif i.find('Mako') >= 0:
        new_Species.append('Shark Mako')          
    elif i.find('Leopard') >= 0:
        new_Species.append('Shark Leopard')
    elif i.find('Raggedtooth') >= 0:
        new_Species.append('Shark Raggedtooth')
    elif i.find('Spinner') >= 0:
        new_Species.append('Shark Spinner')
    elif i.find('Sevengill') >= 0:
        new_Species.append('Shark Sevengill')
    elif i.find('Salmon') >= 0:
        new_Species.append('Shark Salmon')
    elif i.find('Hammerhead') >= 0:
        new_Species.append('Shark Hammerhead')
    elif i.find('Galapagos') >= 0:
        new_Species.append('Shark Galapagos')
    elif i.find('dogfish') >= 0:
        new_Species.append('Shark dogfish')
    elif i.find('Copper') >= 0:
        new_Species.append('Shark Copper')
    elif i.find('Carpet') >= 0:
        new_Species.append('Shark Carpet')           

        
    else:
        new_Species.append("Unknown")
 
data.Species = new_Species

# %%
data.to_csv("/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data pruebas/DataLimpieza90.csv", index=True, sep=';')

# %%
new_Date = []

data['Date'] = data['Date'].astype(str)

for i in data['Date']:
    if i.find('Jan') >= 0 or i.find('jan') >= 0:
        new_Date.append('Jan')
    elif i.find('feb') >= 0 or i.find('Feb') >= 0:
        new_Date.append('Feb')
    elif i.find('Apr') >= 0 or i.find('apr') >= 0:
        new_Date.append('Apr')
    elif i.find('May') >= 0 or i.find('may') >= 0:
        new_Date.append('May')        
    elif i.find('Jun') >= 0 or i.find('jun') >= 0:
        new_Date.append('Jun')
    elif i.find('Jul') >= 0 or i.find('jul') >= 0:
        new_Date.append('Jul')  
    elif i.find('Aug') >= 0 or i.find('aug') >= 0:
        new_Date.append('Aug')
    elif i.find('Sep') >= 0 or i.find('sep') >= 0:
        new_Date.append('Sept')          
    elif i.find('Oct') >= 0 or i.find('oct') >= 0:
        new_Date.append('Oct')
    elif i.find('Nov') >= 0 or i.find('nov') >= 0:
        new_Date.append('Nov')          
    elif i.find('Dec') >= 0 or i.find('dec') >= 0:
        new_Date.append('Dec')
    elif i.find('Mar') >= 0 or i.find('mar') >= 0:
        new_Date.append('Mar')              
    else:
        new_Date.append("Unknown")

#print(new_Date)
data.Date = new_Date

# %%
data.to_csv("/Users/pgr/Documents/Repositorio Proyectos/w2-Project---Clean/Data pruebas/DataLimpieza89.csv", index=True, sep=';')

# %%
data['Time'] = data['Time'].astype(str)

# %%
data['Investigator or source'] = data['Investigator or source'].astype(str)

# %%
#limpiamos valores nulos de Fatal
data['Fatal (y/n)'] = data['Fatal (y/n)'].astype(str)

Normalizar = []
for i in data['Fatal (y/n)']:
    if i == "nan" or i == "UNKNOWN":
        Normalizar.append('Unknown')
    else:
        Normalizar.append(i)

data['Fatal (y/n)'] =  Normalizar

# %%
#limpiamos valores nulos de Type
data['Type'] = data['Type'].astype(str)

Normalizar = []
for i in data['Type']:
    if i == "nan":
        Normalizar.append('Unknown')
    else:
        Normalizar.append(i)


data['Type'] =  Normalizar
